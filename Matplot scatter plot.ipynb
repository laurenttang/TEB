# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# Create data
N = 60
g1 = (0.6 + 0.6 * np.random.rand(N), np.random.rand(N))
g2 = (0.4 + 0.3 * np.random.rand(N), 0.5 * np.random.rand(N))
g3 = (0.3 * np.random.rand(N), 0.3 * np.random.rand(N))
print(g1[1],type(g1[1]))
data = (g1, g2, g3)
colors = ("red", "green", "blue")
groups = ("coffee", "tea", "water")

for data, color, group in zip(data, colors, groups):
    x, y = data
    plt.scatter(x, y, alpha=0.8, c=color, edgecolors='none', s=30, label=group)

plt.legend(loc=2)
plt.title('Matplot scatter plot')
plt.show()
# Out:
# [0.72464998 0.37293505 0.27474363 0.13195843 0.28865235 0.81250693
#  0.54667462 0.94993942 0.98404519 0.75070813 0.04456818 0.28454587
#  0.18967312 0.59450184 0.52472808 0.86953029 0.30701391 0.75800812
#  0.94565459 0.98927301 0.55132278 0.44568468 0.26527753 0.5115166
#  0.21523596 0.71376108 0.23202615 0.1988176  0.51267773 0.16540047
#  0.41213137 0.43689768 0.40023258 0.53205323 0.92485701 0.81143357
#  0.10731813 0.95173378 0.14192567 0.31044824 0.78864773 0.68347561
#  0.69183122 0.53322791 0.35376223 0.56342959 0.64827172 0.46610991
#  0.41323006 0.91752448 0.39352356 0.87778709 0.2161138  0.9286488
#  0.63830289 0.01197813 0.96627326 0.5198193  0.60329626 0.77771547] <class 'numpy.ndarray'>
